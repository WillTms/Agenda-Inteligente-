# %% [markdown]
# <a href="https://colab.research.google.com/github/WillTms/Agenda-Inteligente-/blob/main/Atividade_Grafica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('AAAAAAAAAA')
print('AAAAAAAAAA')
print('AAAAAAAAAA')
# Out:
# AAAAAAAAAA
# AAAAAAAAAA
# AAAAAAAAAA
